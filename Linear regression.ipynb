# %%
import pandas as pd
import matplotlib as mpl
import statsmodels.formula.api as sm
from sklearn.linear_model import LinearRegression
from scipy import stats
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as s

# %%
tb1=pd.read_excel(r"C:\Users\admin\Desktop\repair.xlsx")
tb1
# Out:
#    service_call  monts_since_last_service types_of_repair  \
# 0             1                         2      electrical
# 1             2                         6      mechanical
# 2             3                         8      electrical
# 3             4                         3      mechanical
# 4             5                         2      electrical
# 5             6                         7      electrical
# 6             7                         9      mechanical
# 7             8                         8      mechanical
# 8             9                         4      electrical
# 9            10                         6      electrical
#
#    repair_time_in_hours
# 0                   2.9
# 1                   3.0
# 2                   4.8
# 3                   1.8
# 4                   2.9
# 5                   4.9
# 6                   4.2
# 7                   4.8
# 8                   4.4
# 9                   4.5

# %%
plt.scatter(tb1['monts_since_last_service'],tb1["repair_time_in_hours"],color="green")
plt.ylabel("repair_time_in_hours")
plt.title("Simple Linear Regression")
# Out:
# Text(0.5, 1.0, 'Simple Linear Regression')

# %%
dummy=pd.get_dummies(tb1['types_of_repair'])
dummy
# Out:
#    electrical  mechanical
# 0           1           0
# 1           0           1
# 2           1           0
# 3           0           1
# 4           1           0
# 5           1           0
# 6           0           1
# 7           0           1
# 8           1           0
# 9           1           0

# %%
dummy=pd.get_dummies(tb1['types_of_repair'])
step1=pd.concat([tb1,dummy],axis=1)
step1.drop(['types_of_repair','mechanical'],inplace=True,axis=1)
step1
# Out:
#    service_call  monts_since_last_service  repair_time_in_hours  electrical
# 0             1                         2                   2.9           1
# 1             2                         6                   3.0           0
# 2             3                         8                   4.8           1
# 3             4                         3                   1.8           0
# 4             5                         2                   2.9           1
# 5             6                         7                   4.9           1
# 6             7                         9                   4.2           0
# 7             8                         8                   4.8           0
# 8             9                         4                   4.4           1
# 9            10                         6                   4.5           1
